# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
# Import the datetime module from the datetime library.
from datetime import datetime
# Import the API key.
from config import weather_api_key
import requests
# Import the time module.
import time
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]    
            # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
            # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          #"Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mercedes
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | talnakh
# Processing Record 4 of Set 1 | hobart
# Processing Record 5 of Set 1 | east london
# Processing Record 6 of Set 1 | castro
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | qaanaaq
# Processing Record 9 of Set 1 | pathein
# Processing Record 10 of Set 1 | kuusamo
# Processing Record 11 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 1 | pangkalanbuun
# Processing Record 13 of Set 1 | coos bay
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | tura
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | lorengau
# Processing Record 20 of Set 1 | dunedin
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | faya
# Processing Record 23 of Set 1 | whitehorse
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | guicheng
# City not found. Skipping...
# Processing Record 26 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 27 of Set 1 | krasnoselkup
# Processing Record 28 of Set 1 | bethel
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | kapaa
# Processing Record 31 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 32 of Set 1 | ancud
# Processing Record 33 of Set 1 | saint-philippe
# Processing Record 34 of Set 1 | tasiilaq
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | puerto ayora
# Processing Record 37 of Set 1 | barrow
# Processing Record 38 of Set 1 | kasempa
# Processing Record 39 of Set 1 | andenes
# Processing Record 40 of Set 1 | port alfred
# Processing Record 41 of Set 1 | ahipara
# Processing Record 42 of Set 1 | nishihara
# Processing Record 43 of Set 1 | sao filipe
# Processing Record 44 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 1 | obidos
# Processing Record 46 of Set 1 | ostrovnoy
# Processing Record 47 of Set 1 | hofn
# Processing Record 48 of Set 1 | vestmannaeyjar
# Processing Record 49 of Set 1 | bedele
# Processing Record 50 of Set 1 | sassandra
# Processing Record 1 of Set 2 | chuy
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | kiama
# Processing Record 4 of Set 2 | malakal
# Processing Record 5 of Set 2 | busselton
# Processing Record 6 of Set 2 | cape town
# Processing Record 7 of Set 2 | vanimo
# Processing Record 8 of Set 2 | richards bay
# Processing Record 9 of Set 2 | hilo
# Processing Record 10 of Set 2 | chivilcoy
# Processing Record 11 of Set 2 | batticaloa
# Processing Record 12 of Set 2 | san carlos del zulia
# Processing Record 13 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 14 of Set 2 | sur
# Processing Record 15 of Set 2 | takayama
# Processing Record 16 of Set 2 | yellowknife
# Processing Record 17 of Set 2 | constitucion
# Processing Record 18 of Set 2 | ambanja
# Processing Record 19 of Set 2 | jiexiu
# Processing Record 20 of Set 2 | abu dhabi
# Processing Record 21 of Set 2 | vista hermosa
# Processing Record 22 of Set 2 | faanui
# Processing Record 23 of Set 2 | lebu
# Processing Record 24 of Set 2 | biltine
# Processing Record 25 of Set 2 | flinders
# Processing Record 26 of Set 2 | thompson
# Processing Record 27 of Set 2 | mazagao
# Processing Record 28 of Set 2 | dingle
# Processing Record 29 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 30 of Set 2 | arkhangelskoye
# Processing Record 31 of Set 2 | tuktoyaktuk
# Processing Record 32 of Set 2 | hay river
# Processing Record 33 of Set 2 | eldorado
# Processing Record 34 of Set 2 | tungor
# Processing Record 35 of Set 2 | reguengos de monsaraz
# Processing Record 36 of Set 2 | bredasdorp
# Processing Record 37 of Set 2 | andilamena
# Processing Record 38 of Set 2 | alofi
# Processing Record 39 of Set 2 | bluff
# Processing Record 40 of Set 2 | mar del plata
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | mao
# Processing Record 43 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 44 of Set 2 | port blair
# Processing Record 45 of Set 2 | korla
# Processing Record 46 of Set 2 | gerash
# Processing Record 47 of Set 2 | skjervoy
# Processing Record 48 of Set 2 | kurilsk
# Processing Record 49 of Set 2 | deshna
# City not found. Skipping...
# Processing Record 50 of Set 2 | port elizabeth
# Processing Record 1 of Set 3 | udachnyy
# Processing Record 2 of Set 3 | minatitlan
# Processing Record 3 of Set 3 | broome
# Processing Record 4 of Set 3 | comodoro rivadavia
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | innisfail
# Processing Record 7 of Set 3 | jamestown
# Processing Record 8 of Set 3 | garoua
# Processing Record 9 of Set 3 | izhma
# Processing Record 10 of Set 3 | tupa
# Processing Record 11 of Set 3 | yellamanchili
# City not found. Skipping...
# Processing Record 12 of Set 3 | egvekinot
# Processing Record 13 of Set 3 | tiksi
# Processing Record 14 of Set 3 | poronaysk
# Processing Record 15 of Set 3 | yar-sale
# Processing Record 16 of Set 3 | cherskiy
# Processing Record 17 of Set 3 | yakeshi
# Processing Record 18 of Set 3 | omsukchan
# Processing Record 19 of Set 3 | longyearbyen
# Processing Record 20 of Set 3 | kensington
# Processing Record 21 of Set 3 | coolum beach
# Processing Record 22 of Set 3 | puerto escondido
# Processing Record 23 of Set 3 | mehamn
# Processing Record 24 of Set 3 | tauramena
# Processing Record 25 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 26 of Set 3 | capinzal
# Processing Record 27 of Set 3 | beisfjord
# Processing Record 28 of Set 3 | butaritari
# Processing Record 29 of Set 3 | filingue
# Processing Record 30 of Set 3 | futog
# Processing Record 31 of Set 3 | deputatskiy
# Processing Record 32 of Set 3 | tarudant
# City not found. Skipping...
# Processing Record 33 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 34 of Set 3 | reconquista
# Processing Record 35 of Set 3 | waipawa
# Processing Record 36 of Set 3 | kavieng
# Processing Record 37 of Set 3 | vardo
# Processing Record 38 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 39 of Set 3 | rakek
# Processing Record 40 of Set 3 | half moon bay
# Processing Record 41 of Set 3 | haines junction
# Processing Record 42 of Set 3 | rundu
# Processing Record 43 of Set 3 | geraldton
# Processing Record 44 of Set 3 | bur gabo
# City not found. Skipping...
# Processing Record 45 of Set 3 | saldanha
# Processing Record 46 of Set 3 | dhidhdhoo
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | tuatapere
# Processing Record 49 of Set 3 | hasaki
# Processing Record 50 of Set 3 | victoria
# Processing Record 1 of Set 4 | porto novo
# Processing Record 2 of Set 4 | ambodifototra
# City not found. Skipping...
# Processing Record 3 of Set 4 | dikson
# Processing Record 4 of Set 4 | urumqi
# Processing Record 5 of Set 4 | khatanga
# Processing Record 6 of Set 4 | cumaribo
# City not found. Skipping...
# Processing Record 7 of Set 4 | ylivieska
# Processing Record 8 of Set 4 | shaowu
# Processing Record 9 of Set 4 | upernavik
# Processing Record 10 of Set 4 | goderich
# Processing Record 11 of Set 4 | san policarpo
# Processing Record 12 of Set 4 | severo-kurilsk
# Processing Record 13 of Set 4 | nouakchott
# Processing Record 14 of Set 4 | batagay
# Processing Record 15 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 16 of Set 4 | sobolevo
# Processing Record 17 of Set 4 | bambous virieux
# Processing Record 18 of Set 4 | pangnirtung
# Processing Record 19 of Set 4 | conchas
# Processing Record 20 of Set 4 | aljezur
# Processing Record 21 of Set 4 | ilulissat
# Processing Record 22 of Set 4 | sataua
# City not found. Skipping...
# Processing Record 23 of Set 4 | nikolskoye
# Processing Record 24 of Set 4 | manggar
# Processing Record 25 of Set 4 | lewisburg
# Processing Record 26 of Set 4 | olafsvik
# Processing Record 27 of Set 4 | canaries
# Processing Record 28 of Set 4 | te anau
# Processing Record 29 of Set 4 | benghazi
# Processing Record 30 of Set 4 | moose factory
# Processing Record 31 of Set 4 | kongolo
# Processing Record 32 of Set 4 | margate
# Processing Record 33 of Set 4 | college
# Processing Record 34 of Set 4 | asau
# Processing Record 35 of Set 4 | ritchie
# Processing Record 36 of Set 4 | ankazobe
# Processing Record 37 of Set 4 | gat
# Processing Record 38 of Set 4 | airai
# Processing Record 39 of Set 4 | lircay
# Processing Record 40 of Set 4 | giyani
# Processing Record 41 of Set 4 | katsuura
# Processing Record 42 of Set 4 | singaraja
# Processing Record 43 of Set 4 | adre
# Processing Record 44 of Set 4 | posse
# Processing Record 45 of Set 4 | andevoranto
# City not found. Skipping...
# Processing Record 46 of Set 4 | iqaluit
# Processing Record 47 of Set 4 | riachao das neves
# Processing Record 48 of Set 4 | panuco
# Processing Record 49 of Set 4 | trincomalee
# Processing Record 50 of Set 4 | cidreira
# Processing Record 1 of Set 5 | ribeira grande
# Processing Record 2 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 3 of Set 5 | pampa
# Processing Record 4 of Set 5 | trairi
# Processing Record 5 of Set 5 | shubarkuduk
# Processing Record 6 of Set 5 | torbay
# Processing Record 7 of Set 5 | fairbanks
# Processing Record 8 of Set 5 | adrar
# Processing Record 9 of Set 5 | halalo
# City not found. Skipping...
# Processing Record 10 of Set 5 | hamilton
# Processing Record 11 of Set 5 | lavrentiya
# Processing Record 12 of Set 5 | port augusta
# Processing Record 13 of Set 5 | makrana
# Processing Record 14 of Set 5 | vilcun
# Processing Record 15 of Set 5 | hovd
# Processing Record 16 of Set 5 | xining
# Processing Record 17 of Set 5 | samarai
# Processing Record 18 of Set 5 | wanning
# Processing Record 19 of Set 5 | san patricio
# Processing Record 20 of Set 5 | bowen
# Processing Record 21 of Set 5 | clyde river
# Processing Record 22 of Set 5 | mersing
# Processing Record 23 of Set 5 | kothi
# Processing Record 24 of Set 5 | traverse city
# Processing Record 25 of Set 5 | parvatsar
# Processing Record 26 of Set 5 | the valley
# Processing Record 27 of Set 5 | hithadhoo
# Processing Record 28 of Set 5 | alyangula
# Processing Record 29 of Set 5 | aklavik
# Processing Record 30 of Set 5 | anadyr
# Processing Record 31 of Set 5 | arraial do cabo
# Processing Record 32 of Set 5 | port hedland
# Processing Record 33 of Set 5 | lodwar
# Processing Record 34 of Set 5 | dorado
# Processing Record 35 of Set 5 | maryville
# Processing Record 36 of Set 5 | chipinge
# Processing Record 37 of Set 5 | chapais
# Processing Record 38 of Set 5 | san quintin
# Processing Record 39 of Set 5 | oranjemund
# Processing Record 40 of Set 5 | zagare
# Processing Record 41 of Set 5 | buin
# Processing Record 42 of Set 5 | klaksvik
# Processing Record 43 of Set 5 | mount gambier
# Processing Record 44 of Set 5 | yumen
# Processing Record 45 of Set 5 | huilong
# Processing Record 46 of Set 5 | labutta
# City not found. Skipping...
# Processing Record 47 of Set 5 | mancheral
# Processing Record 48 of Set 5 | pevek
# Processing Record 49 of Set 5 | codrington
# Processing Record 50 of Set 5 | ust-ilimsk
# Processing Record 1 of Set 6 | karratha
# Processing Record 2 of Set 6 | general roca
# Processing Record 3 of Set 6 | kununurra
# Processing Record 4 of Set 6 | podosinovets
# Processing Record 5 of Set 6 | searcy
# Processing Record 6 of Set 6 | ushirombo
# Processing Record 7 of Set 6 | banda aceh
# Processing Record 8 of Set 6 | ucluelet
# Processing Record 9 of Set 6 | poum
# Processing Record 10 of Set 6 | yulara
# Processing Record 11 of Set 6 | port macquarie
# Processing Record 12 of Set 6 | agadir
# Processing Record 13 of Set 6 | sandwick
# Processing Record 14 of Set 6 | raudeberg
# Processing Record 15 of Set 6 | vao
# Processing Record 16 of Set 6 | gumdag
# Processing Record 17 of Set 6 | karkaralinsk
# City not found. Skipping...
# Processing Record 18 of Set 6 | port hawkesbury
# Processing Record 19 of Set 6 | knysna
# Processing Record 20 of Set 6 | little current
# Processing Record 21 of Set 6 | syamzha
# Processing Record 22 of Set 6 | bushenyi
# Processing Record 23 of Set 6 | bonga
# Processing Record 24 of Set 6 | sao joao da barra
# Processing Record 25 of Set 6 | samaniego
# Processing Record 26 of Set 6 | pascagoula
# Processing Record 27 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 28 of Set 6 | isangel
# Processing Record 29 of Set 6 | vila franca do campo
# Processing Record 30 of Set 6 | caravelas
# Processing Record 31 of Set 6 | puerto carreno
# Processing Record 32 of Set 6 | santa cruz del norte
# Processing Record 33 of Set 6 | nanortalik
# Processing Record 34 of Set 6 | beringovskiy
# Processing Record 35 of Set 6 | tucurui
# Processing Record 36 of Set 6 | sabzevar
# Processing Record 37 of Set 6 | inhambane
# Processing Record 38 of Set 6 | lagoa
# Processing Record 39 of Set 6 | tilichiki
# Processing Record 40 of Set 6 | salalah
# Processing Record 41 of Set 6 | lethem
# Processing Record 42 of Set 6 | nichinan
# Processing Record 43 of Set 6 | fortuna
# Processing Record 44 of Set 6 | santa isabel do rio negro
# Processing Record 45 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 46 of Set 6 | sitka
# Processing Record 47 of Set 6 | ulaanbaatar
# Processing Record 48 of Set 6 | sakakah
# Processing Record 49 of Set 6 | meulaboh
# Processing Record 50 of Set 6 | saskylakh
# Processing Record 1 of Set 7 | leh
# Processing Record 2 of Set 7 | curuca
# Processing Record 3 of Set 7 | jijiang
# Processing Record 4 of Set 7 | fairfield
# Processing Record 5 of Set 7 | antalaha
# Processing Record 6 of Set 7 | san jeronimo
# Processing Record 7 of Set 7 | bandar penggaram
# City not found. Skipping...
# Processing Record 8 of Set 7 | brownsville
# Processing Record 9 of Set 7 | san cristobal
# Processing Record 10 of Set 7 | port lincoln
# Processing Record 11 of Set 7 | kendallville
# Processing Record 12 of Set 7 | corowa
# Processing Record 13 of Set 7 | balsas
# Processing Record 14 of Set 7 | atikokan
# Processing Record 15 of Set 7 | marienburg
# Processing Record 16 of Set 7 | port hardy
# Processing Record 17 of Set 7 | ixtapa
# Processing Record 18 of Set 7 | coihaique
# Processing Record 19 of Set 7 | laguna
# Processing Record 20 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 7 | yarim
# Processing Record 22 of Set 7 | mayna
# Processing Record 23 of Set 7 | kaitangata
# Processing Record 24 of Set 7 | cheuskiny
# City not found. Skipping...
# Processing Record 25 of Set 7 | mahebourg
# Processing Record 26 of Set 7 | hermiston
# Processing Record 27 of Set 7 | sibolga
# Processing Record 28 of Set 7 | luquillo
# Processing Record 29 of Set 7 | pandan
# Processing Record 30 of Set 7 | jalu
# Processing Record 31 of Set 7 | souillac
# Processing Record 32 of Set 7 | provideniya
# Processing Record 33 of Set 7 | rudnogorsk
# Processing Record 34 of Set 7 | jasper
# Processing Record 35 of Set 7 | muzhi
# Processing Record 36 of Set 7 | rocha
# Processing Record 37 of Set 7 | clermont
# Processing Record 38 of Set 7 | kavaratti
# Processing Record 39 of Set 7 | yuba city
# Processing Record 40 of Set 7 | coihueco
# Processing Record 41 of Set 7 | beidao
# Processing Record 42 of Set 7 | pacific grove
# Processing Record 43 of Set 7 | plettenberg bay
# Processing Record 44 of Set 7 | aksarka
# Processing Record 45 of Set 7 | ratholo
# Processing Record 46 of Set 7 | suntar
# Processing Record 47 of Set 7 | nalut
# Processing Record 48 of Set 7 | grindavik
# Processing Record 49 of Set 7 | bakchar
# Processing Record 50 of Set 7 | yuxia
# Processing Record 1 of Set 8 | sarangani
# Processing Record 2 of Set 8 | ukiah
# Processing Record 3 of Set 8 | russell
# Processing Record 4 of Set 8 | zhongshu
# Processing Record 5 of Set 8 | uyemskiy
# Processing Record 6 of Set 8 | baganga
# Processing Record 7 of Set 8 | morro bay
# Processing Record 8 of Set 8 | coquimbo
# Processing Record 9 of Set 8 | cabo san lucas
# Processing Record 10 of Set 8 | ust-tsilma
# Processing Record 11 of Set 8 | silistra
# Processing Record 12 of Set 8 | kodinsk
# Processing Record 13 of Set 8 | bilma
# Processing Record 14 of Set 8 | guanare
# Processing Record 15 of Set 8 | lichinga
# Processing Record 16 of Set 8 | burgeo
# Processing Record 17 of Set 8 | nouadhibou
# Processing Record 18 of Set 8 | yeppoon
# Processing Record 19 of Set 8 | lisakovsk
# Processing Record 20 of Set 8 | urulga
# City not found. Skipping...
# Processing Record 21 of Set 8 | saint-georges
# Processing Record 22 of Set 8 | noumea
# Processing Record 23 of Set 8 | saint george
# Processing Record 24 of Set 8 | sanary-sur-mer
# Processing Record 25 of Set 8 | araouane
# Processing Record 26 of Set 8 | ambilobe
# Processing Record 27 of Set 8 | esperance
# Processing Record 28 of Set 8 | zavallya
# Processing Record 29 of Set 8 | kedainiai
# Processing Record 30 of Set 8 | boa vista
# Processing Record 31 of Set 8 | hope
# Processing Record 32 of Set 8 | newport
# Processing Record 33 of Set 8 | polunochnoye
# Processing Record 34 of Set 8 | pisco
# Processing Record 35 of Set 8 | anjozorobe
# Processing Record 36 of Set 8 | yining
# Processing Record 37 of Set 8 | khormuj
# City not found. Skipping...
# Processing Record 38 of Set 8 | harper
# Processing Record 39 of Set 8 | paso de los toros
# Processing Record 40 of Set 8 | villamontes
# Processing Record 41 of Set 8 | kautokeino
# Processing Record 42 of Set 8 | loandjili
# Processing Record 43 of Set 8 | belmonte
# Processing Record 44 of Set 8 | goryachiy klyuch
# Processing Record 45 of Set 8 | sesheke
# Processing Record 46 of Set 8 | oksfjord
# Processing Record 47 of Set 8 | vanavara
# Processing Record 48 of Set 8 | kruisfontein
# Processing Record 49 of Set 8 | ronneby
# Processing Record 50 of Set 8 | kitui
# Processing Record 1 of Set 9 | la herradura
# Processing Record 2 of Set 9 | ponta delgada
# Processing Record 3 of Set 9 | khandyga
# Processing Record 4 of Set 9 | touros
# Processing Record 5 of Set 9 | stokmarknes
# Processing Record 6 of Set 9 | carsamba
# Processing Record 7 of Set 9 | palmer
# Processing Record 8 of Set 9 | matamoros
# Processing Record 9 of Set 9 | lazaro cardenas
# Processing Record 10 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 11 of Set 9 | tyrma
# Processing Record 12 of Set 9 | severnoye
# Processing Record 13 of Set 9 | belgrade
# Processing Record 14 of Set 9 | taltal
# Processing Record 15 of Set 9 | hobyo
# Processing Record 16 of Set 9 | milingimbi
# City not found. Skipping...
# Processing Record 17 of Set 9 | chokurdakh
# Processing Record 18 of Set 9 | penzance
# Processing Record 19 of Set 9 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 9 | mwene-ditu
# Processing Record 21 of Set 9 | kasungu
# Processing Record 22 of Set 9 | matara
# Processing Record 23 of Set 9 | bengkulu
# Processing Record 24 of Set 9 | bonavista
# Processing Record 25 of Set 9 | tamworth
# Processing Record 26 of Set 9 | lolua
# City not found. Skipping...
# Processing Record 27 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 9 | ayan
# Processing Record 29 of Set 9 | northam
# Processing Record 30 of Set 9 | aykhal
# Processing Record 31 of Set 9 | carnarvon
# Processing Record 32 of Set 9 | damaturu
# Processing Record 33 of Set 9 | rafaela
# Processing Record 34 of Set 9 | avila
# Processing Record 35 of Set 9 | albuquerque
# Processing Record 36 of Set 9 | ayagoz
# Processing Record 37 of Set 9 | upington
# Processing Record 38 of Set 9 | theunissen
# Processing Record 39 of Set 9 | lompoc
# Processing Record 40 of Set 9 | cairns
# Processing Record 41 of Set 9 | gawler
# Processing Record 42 of Set 9 | porto belo
# Processing Record 43 of Set 9 | yantai
# Processing Record 44 of Set 9 | beira
# Processing Record 45 of Set 9 | yenagoa
# Processing Record 46 of Set 9 | komsomolskiy
# Processing Record 47 of Set 9 | moroto
# Processing Record 48 of Set 9 | bandarbeyla
# Processing Record 49 of Set 9 | ekibastuz
# Processing Record 50 of Set 9 | jiaocheng
# Processing Record 1 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 10 | ranong
# Processing Record 3 of Set 10 | barcelos
# Processing Record 4 of Set 10 | lieksa
# Processing Record 5 of Set 10 | ercis
# Processing Record 6 of Set 10 | dabat
# Processing Record 7 of Set 10 | mundo nuevo
# Processing Record 8 of Set 10 | warwick
# Processing Record 9 of Set 10 | tadine
# Processing Record 10 of Set 10 | los llanos de aridane
# Processing Record 11 of Set 10 | himora
# City not found. Skipping...
# Processing Record 12 of Set 10 | mount isa
# Processing Record 13 of Set 10 | beloha
# Processing Record 14 of Set 10 | addis zemen
# City not found. Skipping...
# Processing Record 15 of Set 10 | pangai
# Processing Record 16 of Set 10 | oxapampa
# Processing Record 17 of Set 10 | tsihombe
# City not found. Skipping...
# Processing Record 18 of Set 10 | palu
# Processing Record 19 of Set 10 | bombay
# Processing Record 20 of Set 10 | alugan
# Processing Record 21 of Set 10 | kamaishi
# Processing Record 22 of Set 10 | benjamin constant
# Processing Record 23 of Set 10 | bathsheba
# Processing Record 24 of Set 10 | kihei
# Processing Record 25 of Set 10 | sandpoint
# Processing Record 26 of Set 10 | pasan
# Processing Record 27 of Set 10 | amazar
# Processing Record 28 of Set 10 | beyneu
# Processing Record 29 of Set 10 | riyadh
# Processing Record 30 of Set 10 | sisimiut
# Processing Record 31 of Set 10 | monster
# Processing Record 32 of Set 10 | logan lake
# Processing Record 33 of Set 10 | taoudenni
# Processing Record 34 of Set 10 | narsaq
# Processing Record 35 of Set 10 | yushala
# Processing Record 36 of Set 10 | iwamizawa
# Processing Record 37 of Set 10 | ascension
# Processing Record 38 of Set 10 | kudahuvadhoo
# Processing Record 39 of Set 10 | tigil
# Processing Record 40 of Set 10 | alcudia
# Processing Record 41 of Set 10 | goias
# Processing Record 42 of Set 10 | luderitz
# Processing Record 43 of Set 10 | chumphon
# Processing Record 44 of Set 10 | zhezkazgan
# Processing Record 45 of Set 10 | badiraguato
# Processing Record 46 of Set 10 | marsaxlokk
# Processing Record 47 of Set 10 | tanout
# Processing Record 48 of Set 10 | karaton
# Processing Record 49 of Set 10 | basoko
# Processing Record 50 of Set 10 | shahr-e babak
# Processing Record 1 of Set 11 | edmond
# Processing Record 2 of Set 11 | mata de sao joao
# Processing Record 3 of Set 11 | hauterive
# Processing Record 4 of Set 11 | hirara
# Processing Record 5 of Set 11 | port-gentil
# Processing Record 6 of Set 11 | den helder
# Processing Record 7 of Set 11 | alvorada
# Processing Record 8 of Set 11 | mogochin
# City not found. Skipping...
# Processing Record 9 of Set 11 | henties bay
# Processing Record 10 of Set 11 | ulcinj
# Processing Record 11 of Set 11 | gavle
# Processing Record 12 of Set 11 | ocos
# Processing Record 13 of Set 11 | amapa
# Processing Record 14 of Set 11 | rio grande
# Processing Record 15 of Set 11 | lagos
# Processing Record 16 of Set 11 | vilyuysk
# Processing Record 17 of Set 11 | mogocha
# Processing Record 18 of Set 11 | qaqortoq
# Processing Record 19 of Set 11 | zyryanka
# Processing Record 20 of Set 11 | yaring
# Processing Record 21 of Set 11 | necochea
# Processing Record 22 of Set 11 | skelleftea
# Processing Record 23 of Set 11 | rodrigues alves
# Processing Record 24 of Set 11 | toccoa
# Processing Record 25 of Set 11 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 26 of Set 11 | kibala
# Processing Record 27 of Set 11 | kualakapuas
# Processing Record 28 of Set 11 | otjimbingwe
# Processing Record 29 of Set 11 | tanushimaru
# Processing Record 30 of Set 11 | lata
# Processing Record 31 of Set 11 | isla mujeres
# Processing Record 32 of Set 11 | vostok
# Processing Record 33 of Set 11 | san francisco del mar
# Processing Record 34 of Set 11 | mogzon
# Processing Record 35 of Set 11 | shache
# Processing Record 36 of Set 11 | dargaville
# Processing Record 37 of Set 11 | ojo caliente
# Processing Record 38 of Set 11 | wenzhou
# Processing Record 39 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 40 of Set 11 | senekal
# Processing Record 41 of Set 11 | dromolaxia
# Processing Record 42 of Set 11 | san ramon
# Processing Record 43 of Set 11 | olinda
# Processing Record 44 of Set 11 | bilibino
# Processing Record 45 of Set 11 | ketchikan
# Processing Record 46 of Set 11 | bossangoa
# Processing Record 47 of Set 11 | krasnoarmeysk
# Processing Record 48 of Set 11 | gamba
# Processing Record 49 of Set 11 | osypenko
# Processing Record 50 of Set 11 | benicarlo
# Processing Record 1 of Set 12 | elbistan
# Processing Record 2 of Set 12 | coahuayana
# Processing Record 3 of Set 12 | pacifica
# Processing Record 4 of Set 12 | puerto maldonado
# Processing Record 5 of Set 12 | robertson
# Processing Record 6 of Set 12 | nautla
# Processing Record 7 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 8 of Set 12 | timra
# Processing Record 9 of Set 12 | mittagong
# Processing Record 10 of Set 12 | birao
# Processing Record 11 of Set 12 | mechetinskaya
# Processing Record 12 of Set 12 | rio gallegos
# Processing Record 13 of Set 12 | sinnamary
# Processing Record 14 of Set 12 | fallon
# Processing Record 15 of Set 12 | norman wells
# Processing Record 16 of Set 12 | alexandria
# Processing Record 17 of Set 12 | jiazi
# Processing Record 18 of Set 12 | jos
# Processing Record 19 of Set 12 | byron bay
# Processing Record 20 of Set 12 | kiunga
# Processing Record 21 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 22 of Set 12 | utete
# Processing Record 23 of Set 12 | nhulunbuy
# Processing Record 24 of Set 12 | turbat
# Processing Record 25 of Set 12 | christchurch
# Processing Record 26 of Set 12 | muros
# Processing Record 27 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 28 of Set 12 | umm lajj
# Processing Record 29 of Set 12 | novo aripuana
# Processing Record 30 of Set 12 | verkhnyaya inta
# Processing Record 31 of Set 12 | marzuq
# Processing Record 32 of Set 12 | eureka
# Processing Record 33 of Set 12 | kashmor
# Processing Record 34 of Set 12 | dauriya
# Processing Record 35 of Set 12 | ishigaki
# Processing Record 36 of Set 12 | gazli
# Processing Record 37 of Set 12 | westport
# Processing Record 38 of Set 12 | klyuchi
# Processing Record 39 of Set 12 | artyom
# Processing Record 40 of Set 12 | qasigiannguit
# Processing Record 41 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 42 of Set 12 | ajdabiya
# Processing Record 43 of Set 12 | neiafu
# Processing Record 44 of Set 12 | alekseyevsk
# Processing Record 45 of Set 12 | carutapera
# Processing Record 46 of Set 12 | oudtshoorn
# Processing Record 47 of Set 12 | saravan
# Processing Record 48 of Set 12 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 12 | roald
# Processing Record 50 of Set 12 | mariental
# Processing Record 1 of Set 13 | lumberton
# Processing Record 2 of Set 13 | chowchilla
# Processing Record 3 of Set 13 | okandja
# City not found. Skipping...
# Processing Record 4 of Set 13 | plastun
# Processing Record 5 of Set 13 | rawson
# Processing Record 6 of Set 13 | sogdiondon
# City not found. Skipping...
# Processing Record 7 of Set 13 | krasnovishersk
# Processing Record 8 of Set 13 | kahului
# Processing Record 9 of Set 13 | longlac
# City not found. Skipping...
# Processing Record 10 of Set 13 | bingol
# Processing Record 11 of Set 13 | onega
# Processing Record 12 of Set 13 | taclobo
# Processing Record 13 of Set 13 | mahajanga
# Processing Record 14 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 15 of Set 13 | saint-augustin
# Processing Record 16 of Set 13 | teruel
# Processing Record 17 of Set 13 | kohima
# Processing Record 18 of Set 13 | izumo
# Processing Record 19 of Set 13 | toora-khem
# Processing Record 20 of Set 13 | malanje
# Processing Record 21 of Set 13 | tamandare
# Processing Record 22 of Set 13 | grand forks
# Processing Record 23 of Set 13 | rozzano
# Processing Record 24 of Set 13 | palmerston
# Processing Record 25 of Set 13 | ario
# City not found. Skipping...
# Processing Record 26 of Set 13 | tignere
# Processing Record 27 of Set 13 | arlit
# Processing Record 28 of Set 13 | bourges
# Processing Record 29 of Set 13 | devyatka
# City not found. Skipping...
# Processing Record 30 of Set 13 | kikwit
# Processing Record 31 of Set 13 | yerbogachen
# Processing Record 32 of Set 13 | mana
# Processing Record 33 of Set 13 | luanda
# Processing Record 34 of Set 13 | veinticinco de mayo
# Processing Record 35 of Set 13 | valdivia
# Processing Record 36 of Set 13 | iraucuba
# Processing Record 37 of Set 13 | misratah
# Processing Record 38 of Set 13 | udayagiri
# Processing Record 39 of Set 13 | buckingham
# Processing Record 40 of Set 13 | presidencia roque saenz pena
# Processing Record 41 of Set 13 | florence
# Processing Record 42 of Set 13 | carnduff
# Processing Record 43 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 44 of Set 13 | arman
# Processing Record 45 of Set 13 | havoysund
# Processing Record 46 of Set 13 | guerrero negro
# Processing Record 47 of Set 13 | leua
# Processing Record 48 of Set 13 | chifeng
# Processing Record 49 of Set 13 | dhanaula
# Processing Record 50 of Set 13 | lardos
# Processing Record 1 of Set 14 | jieshi
# Processing Record 2 of Set 14 | lloydminster
# Processing Record 3 of Set 14 | nara
# Processing Record 4 of Set 14 | cruzilia
# Processing Record 5 of Set 14 | chihuahua
# Processing Record 6 of Set 14 | cabedelo
# Processing Record 7 of Set 14 | sibenik
# Processing Record 8 of Set 14 | luganville
# Processing Record 9 of Set 14 | mindelo
# Processing Record 10 of Set 14 | oyama
# Processing Record 11 of Set 14 | sunrise manor
# Processing Record 12 of Set 14 | padang
# Processing Record 13 of Set 14 | deniliquin
# Processing Record 14 of Set 14 | minudasht
# Processing Record 15 of Set 14 | turayf
# Processing Record 16 of Set 14 | derzhavinsk
# Processing Record 17 of Set 14 | vila velha
# Processing Record 18 of Set 14 | altay
# Processing Record 19 of Set 14 | tarifa
# Processing Record 20 of Set 14 | yangambi
# Processing Record 21 of Set 14 | kutum
# Processing Record 22 of Set 14 | solikamsk
# Processing Record 23 of Set 14 | naze
# Processing Record 24 of Set 14 | sorata
# Processing Record 25 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 26 of Set 14 | tazovskiy
# Processing Record 27 of Set 14 | san pedro
# Processing Record 28 of Set 14 | camacha
# Processing Record 29 of Set 14 | nemuro
# Processing Record 30 of Set 14 | big spring
# Processing Record 31 of Set 14 | lahaina
# Processing Record 32 of Set 14 | orsha
# Processing Record 33 of Set 14 | lakes entrance
# Processing Record 34 of Set 14 | el tarra
# Processing Record 35 of Set 14 | pembroke
# Processing Record 36 of Set 14 | milton
# Processing Record 37 of Set 14 | auki
# Processing Record 38 of Set 14 | burica
# City not found. Skipping...
# Processing Record 39 of Set 14 | marsa matruh
# Processing Record 40 of Set 14 | miraflores
# Processing Record 41 of Set 14 | manoel urbano
# Processing Record 42 of Set 14 | pallasovka
# Processing Record 43 of Set 14 | nanchang
# Processing Record 44 of Set 14 | bokspits
# City not found. Skipping...
# Processing Record 45 of Set 14 | anchorage
# Processing Record 46 of Set 14 | jiwani
# Processing Record 47 of Set 14 | vilhena
# Processing Record 48 of Set 14 | nedjo
# Processing Record 49 of Set 14 | tanshui
# City not found. Skipping...
# Processing Record 50 of Set 14 | awjilah
# Processing Record 1 of Set 15 | ontario
# Processing Record 2 of Set 15 | qui nhon
# Processing Record 3 of Set 15 | aguadilla
# Processing Record 4 of Set 15 | ciras
# City not found. Skipping...
# Processing Record 5 of Set 15 | aguimes
# Processing Record 6 of Set 15 | rapid valley
# Processing Record 7 of Set 15 | stretford
# Processing Record 8 of Set 15 | mergui
# City not found. Skipping...
# Processing Record 9 of Set 15 | tongren
# Processing Record 10 of Set 15 | zhicheng
# Processing Record 11 of Set 15 | otavi
# Processing Record 12 of Set 15 | houma
# Processing Record 13 of Set 15 | stillwater
# Processing Record 14 of Set 15 | nipawin
# Processing Record 15 of Set 15 | agva
# City not found. Skipping...
# Processing Record 16 of Set 15 | santa maria
# Processing Record 17 of Set 15 | vasterhaninge
# Processing Record 18 of Set 15 | hvammstangi
# City not found. Skipping...
# Processing Record 19 of Set 15 | abiy adi
# City not found. Skipping...
# Processing Record 20 of Set 15 | koscian
# Processing Record 21 of Set 15 | aizkraukle
# Processing Record 22 of Set 15 | hurghada
# Processing Record 23 of Set 15 | bezhanitsy
# Processing Record 24 of Set 15 | leningradskiy
# Processing Record 25 of Set 15 | mushie
# Processing Record 26 of Set 15 | mandan
# Processing Record 27 of Set 15 | shingu
# Processing Record 28 of Set 15 | halifax
# Processing Record 29 of Set 15 | dwarka
# Processing Record 30 of Set 15 | aktau
# Processing Record 31 of Set 15 | micheweni
# Processing Record 32 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 33 of Set 15 | cordele
# Processing Record 34 of Set 15 | manaus
# Processing Record 35 of Set 15 | pamplona
# Processing Record 36 of Set 15 | moranbah
# Processing Record 37 of Set 15 | manitouwadge
# Processing Record 38 of Set 15 | cosamaloapan
# Processing Record 39 of Set 15 | varhaug
# Processing Record 40 of Set 15 | north bend
# Processing Record 41 of Set 15 | acapulco
# Processing Record 42 of Set 15 | hami
# Processing Record 43 of Set 15 | sao joaquim
# Processing Record 44 of Set 15 | mayya
# Processing Record 45 of Set 15 | avera
# Processing Record 46 of Set 15 | yakhroma
# Processing Record 47 of Set 15 | toba
# Processing Record 48 of Set 15 | beberibe
# Processing Record 49 of Set 15 | bairiki
# Processing Record 50 of Set 15 | marathon
# Processing Record 1 of Set 16 | mokhsogollokh
# Processing Record 2 of Set 16 | katobu
# Processing Record 3 of Set 16 | kenai
# Processing Record 4 of Set 16 | bac lieu
# Processing Record 5 of Set 16 | taneatua
# City not found. Skipping...
# Processing Record 6 of Set 16 | nanzhang
# Processing Record 7 of Set 16 | zhangjiakou
# Processing Record 8 of Set 16 | alta floresta
# Processing Record 9 of Set 16 | inuvik
# Processing Record 10 of Set 16 | karauzyak
# City not found. Skipping...
# Processing Record 11 of Set 16 | lusaka
# Processing Record 12 of Set 16 | camopi
# Processing Record 13 of Set 16 | nurobod
# Processing Record 14 of Set 16 | ola
# Processing Record 15 of Set 16 | mangit
# Processing Record 16 of Set 16 | adelaide
# Processing Record 17 of Set 16 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 16 | evensk
# Processing Record 19 of Set 16 | chepareria
# Processing Record 20 of Set 16 | paita
# Processing Record 21 of Set 16 | tolaga bay
# Processing Record 22 of Set 16 | shenjiamen
# Processing Record 23 of Set 16 | coxim
# Processing Record 24 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 25 of Set 16 | caluquembe
# Processing Record 26 of Set 16 | podgornoye
# Processing Record 27 of Set 16 | galesong
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     Mercedes -34.6515  -59.4307     55.00        94          97        4.41
# 1      Rikitea -23.1203 -134.9692     77.25        77          27        6.02
# 2      Talnakh  69.4865   88.3972     12.61        85          98        9.37
# 3       Hobart -42.8794  147.3294     62.60        45          20       19.57
# 4  East London -33.0153   27.9116     64.40        63           0        5.75
# 5       Castro -24.7911  -50.0119     54.70        96          39        2.37
# 6      Ushuaia -54.8000  -68.3000     42.80        93          90        8.05
# 7      Qaanaaq  77.4840  -69.3632     27.88        64           6        9.75
# 8      Pathein  16.7833   94.7333     98.91        31          59       11.03
# 9      Kuusamo  65.9667   29.1833     30.20        74          75       11.50
#
#   Current Description                 Date
# 0     overcast clouds  2021-04-26 06:22:51
# 1          light rain  2021-04-26 06:23:26
# 2     overcast clouds  2021-04-26 06:27:46
# 3          few clouds  2021-04-26 06:25:30
# 4           clear sky  2021-04-26 06:27:34
# 5    scattered clouds  2021-04-26 06:27:46
# 6     overcast clouds  2021-04-26 06:26:55
# 7           clear sky  2021-04-26 06:27:47
# 8       broken clouds  2021-04-26 06:27:47
# 9       broken clouds  2021-04-26 06:27:48

# %%
new_column_order = ["City", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]
city_data_df.head(20)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Mercedes -34.6515  -59.4307     55.00        94          97
# 1         Rikitea -23.1203 -134.9692     77.25        77          27
# 2         Talnakh  69.4865   88.3972     12.61        85          98
# 3          Hobart -42.8794  147.3294     62.60        45          20
# 4     East London -33.0153   27.9116     64.40        63           0
# 5          Castro -24.7911  -50.0119     54.70        96          39
# 6         Ushuaia -54.8000  -68.3000     42.80        93          90
# 7         Qaanaaq  77.4840  -69.3632     27.88        64           6
# 8         Pathein  16.7833   94.7333     98.91        31          59
# 9         Kuusamo  65.9667   29.1833     30.20        74          75
# 10  Pangkalanbuun  -2.6833  111.6167     86.59        69          53
# 11       Coos Bay  43.3665 -124.2179     46.40        93          90
# 12   Punta Arenas -53.1500  -70.9167     42.80       100          90
# 13           Tura  25.5198   90.2201     99.79        15          59
# 14         Atuona  -9.8000 -139.0333     80.24        71          63
# 15          Vaini -21.2000 -175.2000     78.80        89          75
# 16       Lorengau  -2.0226  147.2712     83.80        73          74
# 17        Dunedin -45.8742  170.5036     46.00        75          84
# 18         Albany  42.6001  -73.9662     41.00        56          47
# 19           Faya  18.3851   42.4509     73.40        42          40
#
#     Wind Speed Current Description
# 0         4.41     overcast clouds
# 1         6.02          light rain
# 2         9.37     overcast clouds
# 3        19.57          few clouds
# 4         5.75           clear sky
# 5         2.37    scattered clouds
# 6         8.05     overcast clouds
# 7         9.75           clear sky
# 8        11.03       broken clouds
# 9        11.50       broken clouds
# 10        4.45          light rain
# 11        5.75     overcast clouds
# 12        8.05          light rain
# 13        7.18       broken clouds
# 14       19.35       broken clouds
# 15        3.44          light rain
# 16        2.68       broken clouds
# 17       24.00       broken clouds
# 18        3.00    scattered clouds
# 19        4.12    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
